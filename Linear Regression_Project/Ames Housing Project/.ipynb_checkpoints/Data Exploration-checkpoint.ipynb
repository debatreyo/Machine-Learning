# %%
# for data manipulation and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Ames Housing Dataset

# %%
# import data into dataframe (DF)
df = pd.read_csv(r"D:\ML\Machine Learning_Practical\Linear Regression_Project\Ames Housing Project\data\Ames_Housing_Data.csv")

# %%
df.head()
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       IR1          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
# ...

# %%
# columns (features)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2930 non-null   int64
#  1   MS SubClass      2930 non-null   int64
#  2   MS Zoning        2930 non-null   object
#  3   Lot Frontage     2440 non-null   float64
#  4   Lot Area         2930 non-null   int64
#  5   Street           2930 non-null   object
#  6   Alley            198 non-null    object
#  7   Lot Shape        2930 non-null   object
#  8   Land Contour     2930 non-null   object
#  9   Utilities        2930 non-null   object
#  10  Lot Config       2930 non-null   object
#  11  Land Slope       2930 non-null   object
#  12  Neighborhood     2930 non-null   object
#  13  Condition 1      2930 non-null   object
#  14  Condition 2      2930 non-null   object
#  15  Bldg Type        2930 non-null   object
# ...

# %%
df.describe().transpose()
# Out:
#                   count          mean           std          min  \
# PID              2930.0  7.144645e+08  1.887308e+08  526301100.0
# MS SubClass      2930.0  5.738737e+01  4.263802e+01         20.0
# Lot Frontage     2440.0  6.922459e+01  2.336533e+01         21.0
# Lot Area         2930.0  1.014792e+04  7.880018e+03       1300.0
# Overall Qual     2930.0  6.094881e+00  1.411026e+00          1.0
# Overall Cond     2930.0  5.563140e+00  1.111537e+00          1.0
# Year Built       2930.0  1.971356e+03  3.024536e+01       1872.0
# Year Remod/Add   2930.0  1.984267e+03  2.086029e+01       1950.0
# Mas Vnr Area     2907.0  1.018968e+02  1.791126e+02          0.0
# BsmtFin SF 1     2929.0  4.426296e+02  4.555908e+02          0.0
# BsmtFin SF 2     2929.0  4.972243e+01  1.691685e+02          0.0
# Bsmt Unf SF      2929.0  5.592625e+02  4.394942e+02          0.0
# Total Bsmt SF    2929.0  1.051615e+03  4.406151e+02          0.0
# ...

# %%
# check correlation between all numeric features
# and target variable (SalePrice)

# select all features EXCEPT object data type (str)
numeric_features = df.select_dtypes(exclude=["object"]) 
numeric_corr = numeric_features.corr()["SalePrice"].sort_values(ascending=False)

# %%
# top 10 numeric features with highest correlation with Sale price
numeric_corr[1:11]
# Out:
# Overall Qual      0.799262
# Gr Liv Area       0.706780
# Garage Cars       0.647877
# Garage Area       0.640401
# Total Bsmt SF     0.632280
# 1st Flr SF        0.621676
# Year Built        0.558426
# Full Bath         0.545604
# Year Remod/Add    0.532974
# Garage Yr Blt     0.526965
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## `Overall Qual` Feature

# %% [markdown]
# >**`Overall Qual`**: Rates the overall material and finish of the house\
#        10	Very Excellent\
#        9	Excellent\
#        8	Very Good\
#        7	Good\
#        6	Above Average\
#        5	Average\
#        4	Below Average\
#        3	Fair\
#        2	Poor\
#        1	Very Poor

# %%
# visualize correlation between overall quality of house and sale price
plt.figure(figsize=(6,4), dpi=220)

sns.scatterplot(x="Overall Qual", y="SalePrice", data=df,
           color="#085786", alpha=0.7)

plt.grid(linestyle=":", alpha=0.75)
plt.title("Overall Quality v/s Sale Price")

plt.tight_layout();

# %% [markdown]
# ### Observations
# 1. Some **outlier houses** exist
#     - Ex. Despite **`Overall Qual = 10`** (Highest) still **`SalePrice`** is below houses of lower quality

# %% [markdown]
# ## `Gr Liv Area` Feature

# %% [markdown]
# >**`Gr Liv Area`**: Above grade (ground) living area square feet

# %%
# visualize correlation between Ground living area of house and sale price
plt.figure(figsize=(6,4), dpi=220)

sns.scatterplot(x="Gr Liv Area", y="SalePrice", data=df,
           color="#085786", alpha=0.7)

plt.grid(linestyle=":", alpha=0.75)
plt.title("Ground Living Area v/s Sale Price")

plt.tight_layout();

# %% [markdown]
# ### Observations
# Visualization again reveals some **outlier houses** with relatively **lower `Sale Price`** despite higher **`Gr Liv Area`**.

# %% [markdown]
# ### Outlier Houses

# %%
# DF capturing outliers visualized above
mask = (df["SalePrice"] < 200000) & (df["Overall Qual"] > 8)
outlier_houses = df[mask]

outlier_houses
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1182  533350090           60        RL           NaN     24572   Pave   NaN
# 1498  908154235           60        RL         313.0     63887   Pave   NaN
# 2180  908154195           20        RL         128.0     39290   Pave   NaN
# 2181  908154205           60        RL         130.0     40094   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence  \
# 1182       IR1          Lvl    AllPub  ...         0     NaN   NaN
# 1498       IR3          Bnk    AllPub  ...       480      Gd   NaN
# 2180       IR1          Bnk    AllPub  ...         0     NaN   NaN
# 2181       IR1          Bnk    AllPub  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1182          NaN        0       6    2008        WD           Family
# 1498          NaN        0       1    2008        New         Partial
# ...

# %% [markdown]
# For **training a ML model** such **outliers** can produce **incorrect results**.
# >_Model may not generalize well if trained on dataset with many such outliers._
#
# ### Conclusion
# Need to **remove** such outlier examples before feeding data to ML model for training.

# %% [markdown]
# ## Remove outliers

# %%
# drop outliers

# filter outliers
mask = (df["Gr Liv Area"] > 4000) & (df["SalePrice"] < 300000)
# retrieve index values of outliers
index_to_drop = df[mask].index

# %%
df_NoOutlier = df.drop(labels=index_to_drop, axis=0)

# %%
# new df with outlier houses removed
df_NoOutlier.head()
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  526301100           20        RL         141.0     31770   Pave   NaN
# 1  526350040           20        RH          80.0     11622   Pave   NaN
# 2  526351010           20        RL          81.0     14267   Pave   NaN
# 3  526353030           20        RL          93.0     11160   Pave   NaN
# 4  527105010           60        RL          74.0     13830   Pave   NaN
#
#   Lot Shape Land Contour Utilities  ... Pool Area Pool QC  Fence Misc Feature  \
# 0       IR1          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 1       Reg          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
# 2       IR1          Lvl    AllPub  ...         0     NaN    NaN         Gar2
# 3       Reg          Lvl    AllPub  ...         0     NaN    NaN          NaN
# 4       IR1          Lvl    AllPub  ...         0     NaN  MnPrv          NaN
#
# ...

# %% [markdown]
# ### Visualizing data without the outliers

# %%
# visualize correlation between Ground living area of house and sale price
plt.figure(figsize=(6,4), dpi=220)

sns.scatterplot(x="Gr Liv Area", y="SalePrice", data=df_NoOutlier,
           color="#169480", alpha=0.7)

plt.grid(linestyle=":", alpha=0.75)
plt.title("Ground Living Area v/s Sale Price")

plt.tight_layout();

# %%
# visualize correlation between overall quality of house and sale price
plt.figure(figsize=(6,4), dpi=220)

sns.scatterplot(x="Overall Qual", y="SalePrice", data=df_NoOutlier,
           color="#169480", alpha=0.7)

plt.grid(linestyle=":", alpha=0.75)
plt.title("Overall Quality v/s Sale Price")

plt.tight_layout();

# %% [markdown]
# ## Save Dataframe after removing outliers

# %%
df_NoOutlier.to_csv(r"D:\ML\Machine Learning_Practical\Linear Regression_Project\Ames Housing Project\data\Ames_housing_No_outliers.csv")
